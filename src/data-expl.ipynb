# %%
import tarfile
import os
import shutil

from pydub import AudioSegment
from pydub.playback import play
import IPython
import wave
from scipy.io import wavfile
from scipy.signal import resample
import librosa
import soundfile as sf

import numpy as np
import random

# %%
data_dir = "/Users/glebmokeev/Rask/data"

# %% [markdown]
# ### Calculate total length of music/speech

# %%
def mean_length(directory):
    """Calculates the number of WAV files and their total length in seconds within a directory.

    Args:
        directory (str): The path to the directory containing WAV files.

    Returns:
        tuple: A tuple containing two elements:
            - int: The total number of WAV files found in the directory.
            - float: The total length of all WAV files in seconds.
    """
    wav_count = 0
    sum_length = 0
    failed_files = 0
    for root, dirs, files in os.walk(directory):
        for filename in files:
            try:
                if filename.endswith(".wav"):
                    wav_count += 1
                    with wave.open(os.path.join(root, filename), 'rb') as wav_file:
                        # Get number of frames and sample rate
                        num_frames = wav_file.getnframes()
                        sample_rate = wav_file.getframerate()
                        # Calculate duration in seconds
                        duration = num_frames / float(sample_rate)
                        sum_length += duration
            except:
                failed_files += 1 
    print(f"Failed to proccess {failed_files}")
    return wav_count, sum_length

# %% [markdown]
# ##### music/

# %%
music_count, music_length = mean_length(os.path.join(data_dir, "music/"))
print(f"Number of wavs: {music_count}\nTotal length: {(round(music_length/60/60, 3))} hours \nMean length {round(music_length/music_count, 3)} seconds")
# Out:
# Failed to proccess 473
# Number of wavs: 996
# Total length: 41.423 hours
# Mean length 149.721 seconds

# %% [markdown]
# ##### music/clean

# %%
music_count, music_length = mean_length(os.path.join(data_dir, "music/clean"))
print(f"Number of wavs: {music_count}\nTotal length: {(round(music_length/60/60, 3))} hours \nMean length {round(music_length/music_count, 3)} seconds")
# Out:
# Failed to proccess 75
# Number of wavs: 200
# Total length: 16.294 hours
# Mean length 293.286 seconds

# %% [markdown]
# ##### vocals

# %%
speech_count, speech_length = mean_length(os.path.join(data_dir, "vocals"))
print(f"Number of wavs: {speech_count}\nTotal length: {(round(speech_length/60/60, 3))} hours \nMean length {round(speech_length/speech_count, 3)} seconds")
# Out:
# Failed to proccess 426
# Number of wavs: 5689
# Total length: 68.984 hours
# Mean length 43.653 seconds

# %%
def get_wav_params(wav_file):
  with wave.open(wav_file, 'rb') as wav:
    # Get parameters as a tuple
    params = wav.getparams()

    # Convert parameters to dictionary for easier access
    wav_params = {
        "sample_rate": params[0],
        "channels": params[1],
        "sample_width": params[2],
        "nframes": params[3],
    }

  return wav_params

# %%
get_wav_params("/Users/glebmokeev/Rask/data/music/clean/music-hd-0055.wav")
# Out:
# {'sample_rate': 1, 'channels': 2, 'sample_width': 16000, 'nframes': 1991993}

# %% [markdown]
# ### Resample wavs so they are combinable

# %%
def resample_dir(folder_path, target_sr):
    os.makedirs(os.path.join(folder_path, "resampled"))
    for filename in os.listdir(folder_path):
      if filename.endswith(".wav") and not(filename.startswith("._")):
        # Create the full path to the wav file
        filepath = os.path.join(folder_path, filename)
    
        # Load the audio data
        y, sr = librosa.load(filepath)
    
        # Check if resampling is needed
        if sr != target_sr:
          # Resample the audio to the target rate
          y_resampled = librosa.resample(y, orig_sr=sr, target_sr=target_sr)
    
          new_filename = f"{filename[:-4]}_resampled.wav"  
    
          # Save the resampled audio (overwrite or create new file)
          sf.write(os.path.join(folder_path, "resampled", new_filename), y_resampled, target_sr)
          print(f"Resampled '{filename}' to {target_sr} Hz (saved as '{new_filename}')")
        else:
          print(f"'{filename}' already has sample rate {sr} Hz")

# %%
target_sr = 44100
resample_dir("/Users/glebmokeev/Rask/data/music/clean", target_sr)
# Out:
# Resampled 'music-hd-0056.wav' to 44100 Hz (saved as 'music-hd-0056_resampled.wav')
# Resampled 'musdb-sample97.wav' to 44100 Hz (saved as 'musdb-sample97_resampled.wav')
# Resampled 'musdb-sample83.wav' to 44100 Hz (saved as 'musdb-sample83_resampled.wav')
# Resampled 'music-hd-0042.wav' to 44100 Hz (saved as 'music-hd-0042_resampled.wav')
# Resampled 'musdb-sample54.wav' to 44100 Hz (saved as 'musdb-sample54_resampled.wav')
# Resampled 'musdb-sample40.wav' to 44100 Hz (saved as 'musdb-sample40_resampled.wav')
# Resampled 'musdb-sample68.wav' to 44100 Hz (saved as 'musdb-sample68_resampled.wav')
# Resampled 'musdb-sample69.wav' to 44100 Hz (saved as 'musdb-sample69_resampled.wav')
# Resampled 'musdb-sample41.wav' to 44100 Hz (saved as 'musdb-sample41_resampled.wav')
# Resampled 'musdb-sample55.wav' to 44100 Hz (saved as 'musdb-sample55_resampled.wav')
# Resampled 'music-hd-0043.wav' to 44100 Hz (saved as 'music-hd-0043_resampled.wav')
# Resampled 'musdb-sample82.wav' to 44100 Hz (saved as 'musdb-sample82_resampled.wav')
# Resampled 'musdb-sample96.wav' to 44100 Hz (saved as 'musdb-sample96_resampled.wav')
# Resampled 'music-hd-0057.wav' to 44100 Hz (saved as 'music-hd-0057_resampled.wav')
# Resampled 'musdb-sample80.wav' to 44100 Hz (saved as 'musdb-sample80_resampled.wav')
# Resampled 'music-hd-0041.wav' to 44100 Hz (saved as 'music-hd-0041_resampled.wav')
# Resampled 'music-hd-0055.wav' to 44100 Hz (saved as 'music-hd-0055_resampled.wav')
# Resampled 'musdb-sample94.wav' to 44100 Hz (saved as 'musdb-sample94_resampled.wav')
# Resampled 'music-hd-0069.wav' to 44100 Hz (saved as 'music-hd-0069_resampled.wav')
# Resampled 'musdb-sample43.wav' to 44100 Hz (saved as 'musdb-sample43_resampled.wav')
# Resampled 'musdb-sample57.wav' to 44100 Hz (saved as 'musdb-sample57_resampled.wav')
# Resampled 'musdb-sample56.wav' to 44100 Hz (saved as 'musdb-sample56_resampled.wav')
# Resampled 'musdb-sample42.wav' to 44100 Hz (saved as 'musdb-sample42_resampled.wav')
# Resampled 'music-hd-0068.wav' to 44100 Hz (saved as 'music-hd-0068_resampled.wav')
# Resampled 'musdb-sample95.wav' to 44100 Hz (saved as 'musdb-sample95_resampled.wav')
# Resampled 'music-hd-0054.wav' to 44100 Hz (saved as 'music-hd-0054_resampled.wav')
# Resampled 'music-hd-0040.wav' to 44100 Hz (saved as 'music-hd-0040_resampled.wav')
# Resampled 'musdb-sample81.wav' to 44100 Hz (saved as 'musdb-sample81_resampled.wav')
# Resampled 'musdb-sample149.wav' to 44100 Hz (saved as 'musdb-sample149_resampled.wav')
# Resampled 'musdb-sample85.wav' to 44100 Hz (saved as 'musdb-sample85_resampled.wav')
# Resampled 'music-hd-0044.wav' to 44100 Hz (saved as 'music-hd-0044_resampled.wav')
# Resampled 'music-hd-0050.wav' to 44100 Hz (saved as 'music-hd-0050_resampled.wav')
# Resampled 'musdb-sample91.wav' to 44100 Hz (saved as 'musdb-sample91_resampled.wav')
# Resampled 'musdb-sample46.wav' to 44100 Hz (saved as 'musdb-sample46_resampled.wav')
# Resampled 'musdb-sample52.wav' to 44100 Hz (saved as 'musdb-sample52_resampled.wav')
# Resampled 'musdb-sample53.wav' to 44100 Hz (saved as 'musdb-sample53_resampled.wav')
# Resampled 'musdb-sample47.wav' to 44100 Hz (saved as 'musdb-sample47_resampled.wav')
# Resampled 'musdb-sample90.wav' to 44100 Hz (saved as 'musdb-sample90_resampled.wav')
# Resampled 'music-hd-0051.wav' to 44100 Hz (saved as 'music-hd-0051_resampled.wav')
# Resampled 'music-hd-0045.wav' to 44100 Hz (saved as 'music-hd-0045_resampled.wav')
# Resampled 'musdb-sample84.wav' to 44100 Hz (saved as 'musdb-sample84_resampled.wav')
# Resampled 'musdb-sample148.wav' to 44100 Hz (saved as 'musdb-sample148_resampled.wav')
# Resampled 'music-hd-0053.wav' to 44100 Hz (saved as 'music-hd-0053_resampled.wav')
# Resampled 'musdb-sample92.wav' to 44100 Hz (saved as 'musdb-sample92_resampled.wav')
# Resampled 'musdb-sample86.wav' to 44100 Hz (saved as 'musdb-sample86_resampled.wav')
# Resampled 'music-hd-0047.wav' to 44100 Hz (saved as 'music-hd-0047_resampled.wav')
# Resampled 'musdb-sample79.wav' to 44100 Hz (saved as 'musdb-sample79_resampled.wav')
# Resampled 'musdb-sample51.wav' to 44100 Hz (saved as 'musdb-sample51_resampled.wav')
# Resampled 'musdb-sample45.wav' to 44100 Hz (saved as 'musdb-sample45_resampled.wav')
# Resampled 'musdb-sample44.wav' to 44100 Hz (saved as 'musdb-sample44_resampled.wav')
# Resampled 'musdb-sample50.wav' to 44100 Hz (saved as 'musdb-sample50_resampled.wav')
# Resampled 'musdb-sample78.wav' to 44100 Hz (saved as 'musdb-sample78_resampled.wav')
# Resampled 'music-hd-0046.wav' to 44100 Hz (saved as 'music-hd-0046_resampled.wav')
# Resampled 'musdb-sample87.wav' to 44100 Hz (saved as 'musdb-sample87_resampled.wav')
# Resampled 'musdb-sample93.wav' to 44100 Hz (saved as 'musdb-sample93_resampled.wav')
# Resampled 'music-hd-0052.wav' to 44100 Hz (saved as 'music-hd-0052_resampled.wav')
# Resampled 'musdb-sample104.wav' to 44100 Hz (saved as 'musdb-sample104_resampled.wav')
# Resampled 'musdb-sample7.wav' to 44100 Hz (saved as 'musdb-sample7_resampled.wav')
# Resampled 'musdb-sample110.wav' to 44100 Hz (saved as 'musdb-sample110_resampled.wav')
# Resampled 'musdb-sample138.wav' to 44100 Hz (saved as 'musdb-sample138_resampled.wav')
# Resampled 'music-hd-0035.wav' to 44100 Hz (saved as 'music-hd-0035_resampled.wav')
# Resampled 'music-hd-0021.wav' to 44100 Hz (saved as 'music-hd-0021_resampled.wav')
# Resampled 'music-hd-0009.wav' to 44100 Hz (saved as 'music-hd-0009_resampled.wav')
# Resampled 'musdb-sample37.wav' to 44100 Hz (saved as 'musdb-sample37_resampled.wav')
# Resampled 'musdb-sample23.wav' to 44100 Hz (saved as 'musdb-sample23_resampled.wav')
# Resampled 'musdb-sample22.wav' to 44100 Hz (saved as 'musdb-sample22_resampled.wav')
# Resampled 'musdb-sample36.wav' to 44100 Hz (saved as 'musdb-sample36_resampled.wav')
# Resampled 'music-hd-0008.wav' to 44100 Hz (saved as 'music-hd-0008_resampled.wav')
# Resampled 'music-hd-0020.wav' to 44100 Hz (saved as 'music-hd-0020_resampled.wav')
# Resampled 'music-hd-0034.wav' to 44100 Hz (saved as 'music-hd-0034_resampled.wav')
# Resampled 'musdb-sample139.wav' to 44100 Hz (saved as 'musdb-sample139_resampled.wav')
# Resampled 'musdb-sample111.wav' to 44100 Hz (saved as 'musdb-sample111_resampled.wav')
# Resampled 'musdb-sample6.wav' to 44100 Hz (saved as 'musdb-sample6_resampled.wav')
# Resampled 'musdb-sample105.wav' to 44100 Hz (saved as 'musdb-sample105_resampled.wav')
# Resampled 'musdb-sample113.wav' to 44100 Hz (saved as 'musdb-sample113_resampled.wav')
# Resampled 'musdb-sample107.wav' to 44100 Hz (saved as 'musdb-sample107_resampled.wav')
# Resampled 'musdb-sample4.wav' to 44100 Hz (saved as 'musdb-sample4_resampled.wav')
# Resampled 'music-hd-0022.wav' to 44100 Hz (saved as 'music-hd-0022_resampled.wav')
# Resampled 'music-hd-0036.wav' to 44100 Hz (saved as 'music-hd-0036_resampled.wav')
# Resampled 'musdb-sample20.wav' to 44100 Hz (saved as 'musdb-sample20_resampled.wav')
# Resampled 'musdb-sample34.wav' to 44100 Hz (saved as 'musdb-sample34_resampled.wav')
# Resampled 'musdb-sample35.wav' to 44100 Hz (saved as 'musdb-sample35_resampled.wav')
# Resampled 'musdb-sample21.wav' to 44100 Hz (saved as 'musdb-sample21_resampled.wav')
# Resampled 'music-hd-0037.wav' to 44100 Hz (saved as 'music-hd-0037_resampled.wav')
# Resampled 'music-hd-0023.wav' to 44100 Hz (saved as 'music-hd-0023_resampled.wav')
# Resampled 'musdb-sample5.wav' to 44100 Hz (saved as 'musdb-sample5_resampled.wav')
# Resampled 'musdb-sample106.wav' to 44100 Hz (saved as 'musdb-sample106_resampled.wav')
# Resampled 'musdb-sample112.wav' to 44100 Hz (saved as 'musdb-sample112_resampled.wav')
# Resampled 'musdb-sample116.wav' to 44100 Hz (saved as 'musdb-sample116_resampled.wav')
# Resampled 'musdb-sample102.wav' to 44100 Hz (saved as 'musdb-sample102_resampled.wav')
# Resampled 'musdb-sample1.wav' to 44100 Hz (saved as 'musdb-sample1_resampled.wav')
# Resampled 'music-hd-0027.wav' to 44100 Hz (saved as 'music-hd-0027_resampled.wav')
# Resampled 'music-hd-0033.wav' to 44100 Hz (saved as 'music-hd-0033_resampled.wav')
# Resampled 'musdb-sample19.wav' to 44100 Hz (saved as 'musdb-sample19_resampled.wav')
# Resampled 'musdb-sample25.wav' to 44100 Hz (saved as 'musdb-sample25_resampled.wav')
# Resampled 'musdb-sample31.wav' to 44100 Hz (saved as 'musdb-sample31_resampled.wav')
# Resampled 'musdb-sample30.wav' to 44100 Hz (saved as 'musdb-sample30_resampled.wav')
# Resampled 'musdb-sample24.wav' to 44100 Hz (saved as 'musdb-sample24_resampled.wav')
# Resampled 'musdb-sample18.wav' to 44100 Hz (saved as 'musdb-sample18_resampled.wav')
# Resampled 'music-hd-0032.wav' to 44100 Hz (saved as 'music-hd-0032_resampled.wav')
# Resampled 'music-hd-0026.wav' to 44100 Hz (saved as 'music-hd-0026_resampled.wav')
# Resampled 'musdb-sample103.wav' to 44100 Hz (saved as 'musdb-sample103_resampled.wav')
# Resampled 'musdb-sample117.wav' to 44100 Hz (saved as 'musdb-sample117_resampled.wav')
# Resampled 'musdb-sample129.wav' to 44100 Hz (saved as 'musdb-sample129_resampled.wav')
# Resampled 'musdb-sample101.wav' to 44100 Hz (saved as 'musdb-sample101_resampled.wav')
# Resampled 'musdb-sample2.wav' to 44100 Hz (saved as 'musdb-sample2_resampled.wav')
# Resampled 'musdb-sample115.wav' to 44100 Hz (saved as 'musdb-sample115_resampled.wav')
# Resampled 'music-hd-0018.wav' to 44100 Hz (saved as 'music-hd-0018_resampled.wav')
# Resampled 'music-hd-0030.wav' to 44100 Hz (saved as 'music-hd-0030_resampled.wav')
# Resampled 'music-hd-0024.wav' to 44100 Hz (saved as 'music-hd-0024_resampled.wav')
# Resampled 'musdb-sample32.wav' to 44100 Hz (saved as 'musdb-sample32_resampled.wav')
# Resampled 'musdb-sample26.wav' to 44100 Hz (saved as 'musdb-sample26_resampled.wav')
# Resampled 'musdb-sample27.wav' to 44100 Hz (saved as 'musdb-sample27_resampled.wav')
# Resampled 'musdb-sample33.wav' to 44100 Hz (saved as 'musdb-sample33_resampled.wav')
# Resampled 'music-hd-0025.wav' to 44100 Hz (saved as 'music-hd-0025_resampled.wav')
# Resampled 'music-hd-0031.wav' to 44100 Hz (saved as 'music-hd-0031_resampled.wav')
# Resampled 'music-hd-0019.wav' to 44100 Hz (saved as 'music-hd-0019_resampled.wav')
# Resampled 'musdb-sample114.wav' to 44100 Hz (saved as 'musdb-sample114_resampled.wav')
# Resampled 'musdb-sample3.wav' to 44100 Hz (saved as 'musdb-sample3_resampled.wav')
# Resampled 'musdb-sample100.wav' to 44100 Hz (saved as 'musdb-sample100_resampled.wav')
# Resampled 'musdb-sample128.wav' to 44100 Hz (saved as 'musdb-sample128_resampled.wav')
# Resampled 'musdb-sample125.wav' to 44100 Hz (saved as 'musdb-sample125_resampled.wav')
# Resampled 'musdb-sample131.wav' to 44100 Hz (saved as 'musdb-sample131_resampled.wav')
# Resampled 'musdb-sample119.wav' to 44100 Hz (saved as 'musdb-sample119_resampled.wav')
# Resampled 'music-hd-0014.wav' to 44100 Hz (saved as 'music-hd-0014_resampled.wav')
# Resampled 'music-hd-0000.wav' to 44100 Hz (saved as 'music-hd-0000_resampled.wav')
# Resampled 'music-hd-0028.wav' to 44100 Hz (saved as 'music-hd-0028_resampled.wav')
# Resampled 'musdb-sample16.wav' to 44100 Hz (saved as 'musdb-sample16_resampled.wav')
# Resampled 'musdb-sample17.wav' to 44100 Hz (saved as 'musdb-sample17_resampled.wav')
# Resampled 'music-hd-0029.wav' to 44100 Hz (saved as 'music-hd-0029_resampled.wav')
# Resampled 'music-hd-0001.wav' to 44100 Hz (saved as 'music-hd-0001_resampled.wav')
# Resampled 'music-hd-0015.wav' to 44100 Hz (saved as 'music-hd-0015_resampled.wav')
# Resampled 'musdb-sample118.wav' to 44100 Hz (saved as 'musdb-sample118_resampled.wav')
# Resampled 'musdb-sample130.wav' to 44100 Hz (saved as 'musdb-sample130_resampled.wav')
# Resampled 'musdb-sample124.wav' to 44100 Hz (saved as 'musdb-sample124_resampled.wav')
# Resampled 'musdb-sample132.wav' to 44100 Hz (saved as 'musdb-sample132_resampled.wav')
# Resampled 'musdb-sample126.wav' to 44100 Hz (saved as 'musdb-sample126_resampled.wav')
# Resampled 'music-hd-0003.wav' to 44100 Hz (saved as 'music-hd-0003_resampled.wav')
# Resampled 'music-hd-0017.wav' to 44100 Hz (saved as 'music-hd-0017_resampled.wav')
# Resampled 'musdb-sample15.wav' to 44100 Hz (saved as 'musdb-sample15_resampled.wav')
# Resampled 'musdb-sample29.wav' to 44100 Hz (saved as 'musdb-sample29_resampled.wav')
# Resampled 'musdb-sample28.wav' to 44100 Hz (saved as 'musdb-sample28_resampled.wav')
# Resampled 'musdb-sample14.wav' to 44100 Hz (saved as 'musdb-sample14_resampled.wav')
# Resampled 'music-hd-0016.wav' to 44100 Hz (saved as 'music-hd-0016_resampled.wav')
# Resampled 'music-hd-0002.wav' to 44100 Hz (saved as 'music-hd-0002_resampled.wav')
# Resampled 'musdb-sample127.wav' to 44100 Hz (saved as 'musdb-sample127_resampled.wav')
# Resampled 'musdb-sample133.wav' to 44100 Hz (saved as 'musdb-sample133_resampled.wav')
# Resampled 'musdb-sample8.wav' to 44100 Hz (saved as 'musdb-sample8_resampled.wav')
# Resampled 'musdb-sample137.wav' to 44100 Hz (saved as 'musdb-sample137_resampled.wav')
# Resampled 'musdb-sample123.wav' to 44100 Hz (saved as 'musdb-sample123_resampled.wav')
# Resampled 'music-hd-0006.wav' to 44100 Hz (saved as 'music-hd-0006_resampled.wav')
# Resampled 'music-hd-0012.wav' to 44100 Hz (saved as 'music-hd-0012_resampled.wav')
# Resampled 'musdb-sample38.wav' to 44100 Hz (saved as 'musdb-sample38_resampled.wav')
# Resampled 'musdb-sample10.wav' to 44100 Hz (saved as 'musdb-sample10_resampled.wav')
# Resampled 'musdb-sample11.wav' to 44100 Hz (saved as 'musdb-sample11_resampled.wav')
# Resampled 'musdb-sample39.wav' to 44100 Hz (saved as 'musdb-sample39_resampled.wav')
# Resampled 'music-hd-0013.wav' to 44100 Hz (saved as 'music-hd-0013_resampled.wav')
# Resampled 'music-hd-0007.wav' to 44100 Hz (saved as 'music-hd-0007_resampled.wav')
# Resampled 'musdb-sample122.wav' to 44100 Hz (saved as 'musdb-sample122_resampled.wav')
# Resampled 'musdb-sample136.wav' to 44100 Hz (saved as 'musdb-sample136_resampled.wav')
# Resampled 'musdb-sample9.wav' to 44100 Hz (saved as 'musdb-sample9_resampled.wav')
# Resampled 'musdb-sample108.wav' to 44100 Hz (saved as 'musdb-sample108_resampled.wav')
# Resampled 'musdb-sample120.wav' to 44100 Hz (saved as 'musdb-sample120_resampled.wav')
# Resampled 'musdb-sample134.wav' to 44100 Hz (saved as 'musdb-sample134_resampled.wav')
# Resampled 'music-hd-0039.wav' to 44100 Hz (saved as 'music-hd-0039_resampled.wav')
# Resampled 'music-hd-0011.wav' to 44100 Hz (saved as 'music-hd-0011_resampled.wav')
# Resampled 'music-hd-0005.wav' to 44100 Hz (saved as 'music-hd-0005_resampled.wav')
# Resampled 'musdb-sample13.wav' to 44100 Hz (saved as 'musdb-sample13_resampled.wav')
# Resampled 'musdb-sample12.wav' to 44100 Hz (saved as 'musdb-sample12_resampled.wav')
# Resampled 'music-hd-0004.wav' to 44100 Hz (saved as 'music-hd-0004_resampled.wav')
# Resampled 'music-hd-0010.wav' to 44100 Hz (saved as 'music-hd-0010_resampled.wav')
# Resampled 'music-hd-0038.wav' to 44100 Hz (saved as 'music-hd-0038_resampled.wav')
# Resampled 'musdb-sample135.wav' to 44100 Hz (saved as 'musdb-sample135_resampled.wav')
# Resampled 'musdb-sample121.wav' to 44100 Hz (saved as 'musdb-sample121_resampled.wav')
# Resampled 'musdb-sample109.wav' to 44100 Hz (saved as 'musdb-sample109_resampled.wav')
# Resampled 'musdb-sample146.wav' to 44100 Hz (saved as 'musdb-sample146_resampled.wav')
# Resampled 'music-hd-0063.wav' to 44100 Hz (saved as 'music-hd-0063_resampled.wav')
# Resampled 'musdb-sample75.wav' to 44100 Hz (saved as 'musdb-sample75_resampled.wav')
# Resampled 'musdb-sample61.wav' to 44100 Hz (saved as 'musdb-sample61_resampled.wav')
# Resampled 'musdb-sample49.wav' to 44100 Hz (saved as 'musdb-sample49_resampled.wav')
# Resampled 'musdb-sample48.wav' to 44100 Hz (saved as 'musdb-sample48_resampled.wav')
# Resampled 'musdb-sample60.wav' to 44100 Hz (saved as 'musdb-sample60_resampled.wav')
# Resampled 'musdb-sample74.wav' to 44100 Hz (saved as 'musdb-sample74_resampled.wav')
# Resampled 'music-hd-0062.wav' to 44100 Hz (saved as 'music-hd-0062_resampled.wav')
# Resampled 'musdb-sample147.wav' to 44100 Hz (saved as 'musdb-sample147_resampled.wav')
# Resampled 'musdb-sample145.wav' to 44100 Hz (saved as 'musdb-sample145_resampled.wav')
# Resampled 'music-hd-0060.wav' to 44100 Hz (saved as 'music-hd-0060_resampled.wav')
# Resampled 'music-hd-0074.wav' to 44100 Hz (saved as 'music-hd-0074_resampled.wav')
# Resampled 'music-hd-0048.wav' to 44100 Hz (saved as 'music-hd-0048_resampled.wav')
# Resampled 'musdb-sample89.wav' to 44100 Hz (saved as 'musdb-sample89_resampled.wav')
# Resampled 'musdb-sample62.wav' to 44100 Hz (saved as 'musdb-sample62_resampled.wav')
# Resampled 'musdb-sample76.wav' to 44100 Hz (saved as 'musdb-sample76_resampled.wav')
# Resampled 'musdb-sample77.wav' to 44100 Hz (saved as 'musdb-sample77_resampled.wav')
# Resampled 'musdb-sample63.wav' to 44100 Hz (saved as 'musdb-sample63_resampled.wav')
# Resampled 'musdb-sample88.wav' to 44100 Hz (saved as 'musdb-sample88_resampled.wav')
# Resampled 'music-hd-0049.wav' to 44100 Hz (saved as 'music-hd-0049_resampled.wav')
# Resampled 'music-hd-0061.wav' to 44100 Hz (saved as 'music-hd-0061_resampled.wav')
# Resampled 'musdb-sample144.wav' to 44100 Hz (saved as 'musdb-sample144_resampled.wav')
# Resampled 'musdb-sample150.wav' to 44100 Hz (saved as 'musdb-sample150_resampled.wav')
# Resampled 'musdb-sample140.wav' to 44100 Hz (saved as 'musdb-sample140_resampled.wav')
# Resampled 'musdb-sample98.wav' to 44100 Hz (saved as 'musdb-sample98_resampled.wav')
# Resampled 'music-hd-0059.wav' to 44100 Hz (saved as 'music-hd-0059_resampled.wav')
# Resampled 'music-hd-0065.wav' to 44100 Hz (saved as 'music-hd-0065_resampled.wav')
# Resampled 'music-hd-0071.wav' to 44100 Hz (saved as 'music-hd-0071_resampled.wav')
# Resampled 'musdb-sample67.wav' to 44100 Hz (saved as 'musdb-sample67_resampled.wav')
# Resampled 'musdb-sample73.wav' to 44100 Hz (saved as 'musdb-sample73_resampled.wav')
# Resampled 'musdb-sample72.wav' to 44100 Hz (saved as 'musdb-sample72_resampled.wav')
# Resampled 'musdb-sample66.wav' to 44100 Hz (saved as 'musdb-sample66_resampled.wav')
# Resampled 'music-hd-0070.wav' to 44100 Hz (saved as 'music-hd-0070_resampled.wav')
# Resampled 'music-hd-0064.wav' to 44100 Hz (saved as 'music-hd-0064_resampled.wav')
# Resampled 'music-hd-0058.wav' to 44100 Hz (saved as 'music-hd-0058_resampled.wav')
# Resampled 'musdb-sample99.wav' to 44100 Hz (saved as 'musdb-sample99_resampled.wav')
# Resampled 'musdb-sample141.wav' to 44100 Hz (saved as 'musdb-sample141_resampled.wav')
# Resampled 'musdb-sample143.wav' to 44100 Hz (saved as 'musdb-sample143_resampled.wav')
# Resampled 'music-hd-0072.wav' to 44100 Hz (saved as 'music-hd-0072_resampled.wav')
# Resampled 'music-hd-0066.wav' to 44100 Hz (saved as 'music-hd-0066_resampled.wav')
# Resampled 'musdb-sample58.wav' to 44100 Hz (saved as 'musdb-sample58_resampled.wav')
# Resampled 'musdb-sample70.wav' to 44100 Hz (saved as 'musdb-sample70_resampled.wav')
# Resampled 'musdb-sample64.wav' to 44100 Hz (saved as 'musdb-sample64_resampled.wav')
# Resampled 'musdb-sample65.wav' to 44100 Hz (saved as 'musdb-sample65_resampled.wav')
# Resampled 'musdb-sample71.wav' to 44100 Hz (saved as 'musdb-sample71_resampled.wav')
# Resampled 'musdb-sample59.wav' to 44100 Hz (saved as 'musdb-sample59_resampled.wav')
# Resampled 'music-hd-0067.wav' to 44100 Hz (saved as 'music-hd-0067_resampled.wav')
# Resampled 'music-hd-0073.wav' to 44100 Hz (saved as 'music-hd-0073_resampled.wav')
# Resampled 'musdb-sample142.wav' to 44100 Hz (saved as 'musdb-sample142_resampled.wav')

# %%
target_sr = 44100
resample_dir("/Users/glebmokeev/Rask/data/vocals/mixed/audio", target_sr)
# Out:
# Resampled 'speech-librivox-0076.wav' to 44100 Hz (saved as 'speech-librivox-0076_resampled.wav')
# Resampled 'speech-librivox-0062.wav' to 44100 Hz (saved as 'speech-librivox-0062_resampled.wav')
# Resampled 'speech-librivox-0089.wav' to 44100 Hz (saved as 'speech-librivox-0089_resampled.wav')
# Resampled 'speech-librivox-0102.wav' to 44100 Hz (saved as 'speech-librivox-0102_resampled.wav')
# Resampled 'speech-librivox-0116.wav' to 44100 Hz (saved as 'speech-librivox-0116_resampled.wav')
# Resampled 'speech-librivox-0117.wav' to 44100 Hz (saved as 'speech-librivox-0117_resampled.wav')
# Resampled 'speech-librivox-0103.wav' to 44100 Hz (saved as 'speech-librivox-0103_resampled.wav')
# Resampled 'speech-librivox-0088.wav' to 44100 Hz (saved as 'speech-librivox-0088_resampled.wav')
# Resampled 'speech-librivox-0063.wav' to 44100 Hz (saved as 'speech-librivox-0063_resampled.wav')
# Resampled 'speech-librivox-0077.wav' to 44100 Hz (saved as 'speech-librivox-0077_resampled.wav')
# Resampled 'speech-librivox-0049.wav' to 44100 Hz (saved as 'speech-librivox-0049_resampled.wav')
# Resampled 'speech-librivox-0061.wav' to 44100 Hz (saved as 'speech-librivox-0061_resampled.wav')
# Resampled 'speech-librivox-0075.wav' to 44100 Hz (saved as 'speech-librivox-0075_resampled.wav')
# Resampled 'speech-librivox-0129.wav' to 44100 Hz (saved as 'speech-librivox-0129_resampled.wav')
# Resampled 'speech-librivox-0115.wav' to 44100 Hz (saved as 'speech-librivox-0115_resampled.wav')
# Resampled 'speech-librivox-0101.wav' to 44100 Hz (saved as 'speech-librivox-0101_resampled.wav')
# Resampled 'speech-librivox-0100.wav' to 44100 Hz (saved as 'speech-librivox-0100_resampled.wav')
# Resampled 'speech-librivox-0114.wav' to 44100 Hz (saved as 'speech-librivox-0114_resampled.wav')
# Resampled 'speech-librivox-0128.wav' to 44100 Hz (saved as 'speech-librivox-0128_resampled.wav')
# Resampled 'speech-librivox-0074.wav' to 44100 Hz (saved as 'speech-librivox-0074_resampled.wav')
# Resampled 'speech-librivox-0060.wav' to 44100 Hz (saved as 'speech-librivox-0060_resampled.wav')
# Resampled 'speech-librivox-0048.wav' to 44100 Hz (saved as 'speech-librivox-0048_resampled.wav')
# Resampled 'speech-librivox-0064.wav' to 44100 Hz (saved as 'speech-librivox-0064_resampled.wav')
# Resampled 'speech-librivox-0070.wav' to 44100 Hz (saved as 'speech-librivox-0070_resampled.wav')
# Resampled 'speech-librivox-0058.wav' to 44100 Hz (saved as 'speech-librivox-0058_resampled.wav')
# Resampled 'speech-librivox-0110.wav' to 44100 Hz (saved as 'speech-librivox-0110_resampled.wav')
# Resampled 'speech-librivox-0104.wav' to 44100 Hz (saved as 'speech-librivox-0104_resampled.wav')
# Resampled 'speech-librivox-0138.wav' to 44100 Hz (saved as 'speech-librivox-0138_resampled.wav')
# Resampled 'speech-librivox-0139.wav' to 44100 Hz (saved as 'speech-librivox-0139_resampled.wav')
# Resampled 'speech-librivox-0105.wav' to 44100 Hz (saved as 'speech-librivox-0105_resampled.wav')
# Resampled 'speech-librivox-0111.wav' to 44100 Hz (saved as 'speech-librivox-0111_resampled.wav')
# Resampled 'speech-librivox-0059.wav' to 44100 Hz (saved as 'speech-librivox-0059_resampled.wav')
# Resampled 'speech-librivox-0071.wav' to 44100 Hz (saved as 'speech-librivox-0071_resampled.wav')
# Resampled 'speech-librivox-0065.wav' to 44100 Hz (saved as 'speech-librivox-0065_resampled.wav')
# Resampled 'speech-librivox-0073.wav' to 44100 Hz (saved as 'speech-librivox-0073_resampled.wav')
# Resampled 'speech-librivox-0067.wav' to 44100 Hz (saved as 'speech-librivox-0067_resampled.wav')
# Resampled 'speech-librivox-0098.wav' to 44100 Hz (saved as 'speech-librivox-0098_resampled.wav')
# Resampled 'speech-librivox-0107.wav' to 44100 Hz (saved as 'speech-librivox-0107_resampled.wav')
# Resampled 'speech-librivox-0113.wav' to 44100 Hz (saved as 'speech-librivox-0113_resampled.wav')
# Resampled 'speech-librivox-0112.wav' to 44100 Hz (saved as 'speech-librivox-0112_resampled.wav')
# Resampled 'speech-librivox-0106.wav' to 44100 Hz (saved as 'speech-librivox-0106_resampled.wav')
# Resampled 'speech-librivox-0099.wav' to 44100 Hz (saved as 'speech-librivox-0099_resampled.wav')
# Resampled 'speech-librivox-0066.wav' to 44100 Hz (saved as 'speech-librivox-0066_resampled.wav')
# Resampled 'speech-librivox-0072.wav' to 44100 Hz (saved as 'speech-librivox-0072_resampled.wav')
# Resampled 'speech-librivox-0029.wav' to 44100 Hz (saved as 'speech-librivox-0029_resampled.wav')
# Resampled 'speech-librivox-0015.wav' to 44100 Hz (saved as 'speech-librivox-0015_resampled.wav')
# Resampled 'speech-librivox-0001.wav' to 44100 Hz (saved as 'speech-librivox-0001_resampled.wav')
# Resampled 'speech-librivox-0149.wav' to 44100 Hz (saved as 'speech-librivox-0149_resampled.wav')
# Resampled 'speech-librivox-0161.wav' to 44100 Hz (saved as 'speech-librivox-0161_resampled.wav')
# Resampled 'speech-librivox-0160.wav' to 44100 Hz (saved as 'speech-librivox-0160_resampled.wav')
# Resampled 'speech-librivox-0148.wav' to 44100 Hz (saved as 'speech-librivox-0148_resampled.wav')
# Resampled 'speech-librivox-0000.wav' to 44100 Hz (saved as 'speech-librivox-0000_resampled.wav')
# Resampled 'speech-librivox-0014.wav' to 44100 Hz (saved as 'speech-librivox-0014_resampled.wav')
# Resampled 'speech-librivox-0028.wav' to 44100 Hz (saved as 'speech-librivox-0028_resampled.wav')
# Resampled 'speech-librivox-0002.wav' to 44100 Hz (saved as 'speech-librivox-0002_resampled.wav')
# Resampled 'speech-librivox-0016.wav' to 44100 Hz (saved as 'speech-librivox-0016_resampled.wav')
# Resampled 'speech-librivox-0162.wav' to 44100 Hz (saved as 'speech-librivox-0162_resampled.wav')
# Resampled 'speech-librivox-0163.wav' to 44100 Hz (saved as 'speech-librivox-0163_resampled.wav')
# Resampled 'speech-librivox-0017.wav' to 44100 Hz (saved as 'speech-librivox-0017_resampled.wav')
# Resampled 'speech-librivox-0003.wav' to 44100 Hz (saved as 'speech-librivox-0003_resampled.wav')
# Resampled 'speech-librivox-0007.wav' to 44100 Hz (saved as 'speech-librivox-0007_resampled.wav')
# Resampled 'speech-librivox-0013.wav' to 44100 Hz (saved as 'speech-librivox-0013_resampled.wav')
# Resampled 'speech-librivox-0167.wav' to 44100 Hz (saved as 'speech-librivox-0167_resampled.wav')
# Resampled 'speech-librivox-0166.wav' to 44100 Hz (saved as 'speech-librivox-0166_resampled.wav')
# Resampled 'speech-librivox-0172.wav' to 44100 Hz (saved as 'speech-librivox-0172_resampled.wav')
# Resampled 'speech-librivox-0012.wav' to 44100 Hz (saved as 'speech-librivox-0012_resampled.wav')
# Resampled 'speech-librivox-0006.wav' to 44100 Hz (saved as 'speech-librivox-0006_resampled.wav')
# Resampled 'speech-librivox-0010.wav' to 44100 Hz (saved as 'speech-librivox-0010_resampled.wav')
# Resampled 'speech-librivox-0004.wav' to 44100 Hz (saved as 'speech-librivox-0004_resampled.wav')
# Resampled 'speech-librivox-0038.wav' to 44100 Hz (saved as 'speech-librivox-0038_resampled.wav')
# Resampled 'speech-librivox-0164.wav' to 44100 Hz (saved as 'speech-librivox-0164_resampled.wav')
# Resampled 'speech-librivox-0170.wav' to 44100 Hz (saved as 'speech-librivox-0170_resampled.wav')
# Resampled 'speech-librivox-0158.wav' to 44100 Hz (saved as 'speech-librivox-0158_resampled.wav')
# Resampled 'speech-librivox-0159.wav' to 44100 Hz (saved as 'speech-librivox-0159_resampled.wav')
# Resampled 'speech-librivox-0171.wav' to 44100 Hz (saved as 'speech-librivox-0171_resampled.wav')
# Resampled 'speech-librivox-0165.wav' to 44100 Hz (saved as 'speech-librivox-0165_resampled.wav')
# Resampled 'speech-librivox-0039.wav' to 44100 Hz (saved as 'speech-librivox-0039_resampled.wav')
# Resampled 'speech-librivox-0005.wav' to 44100 Hz (saved as 'speech-librivox-0005_resampled.wav')
# Resampled 'speech-librivox-0011.wav' to 44100 Hz (saved as 'speech-librivox-0011_resampled.wav')
# Resampled 'speech-librivox-0008.wav' to 44100 Hz (saved as 'speech-librivox-0008_resampled.wav')
# Resampled 'speech-librivox-0034.wav' to 44100 Hz (saved as 'speech-librivox-0034_resampled.wav')
# Resampled 'speech-librivox-0020.wav' to 44100 Hz (saved as 'speech-librivox-0020_resampled.wav')
# Resampled 'speech-librivox-0168.wav' to 44100 Hz (saved as 'speech-librivox-0168_resampled.wav')
# Resampled 'speech-librivox-0140.wav' to 44100 Hz (saved as 'speech-librivox-0140_resampled.wav')
# Resampled 'speech-librivox-0154.wav' to 44100 Hz (saved as 'speech-librivox-0154_resampled.wav')
# Resampled 'speech-librivox-0155.wav' to 44100 Hz (saved as 'speech-librivox-0155_resampled.wav')
# Resampled 'speech-librivox-0141.wav' to 44100 Hz (saved as 'speech-librivox-0141_resampled.wav')
# Resampled 'speech-librivox-0169.wav' to 44100 Hz (saved as 'speech-librivox-0169_resampled.wav')
# Resampled 'speech-librivox-0021.wav' to 44100 Hz (saved as 'speech-librivox-0021_resampled.wav')
# Resampled 'speech-librivox-0035.wav' to 44100 Hz (saved as 'speech-librivox-0035_resampled.wav')
# Resampled 'speech-librivox-0009.wav' to 44100 Hz (saved as 'speech-librivox-0009_resampled.wav')
# Resampled 'speech-librivox-0023.wav' to 44100 Hz (saved as 'speech-librivox-0023_resampled.wav')
# Resampled 'speech-librivox-0037.wav' to 44100 Hz (saved as 'speech-librivox-0037_resampled.wav')
# Resampled 'speech-librivox-0157.wav' to 44100 Hz (saved as 'speech-librivox-0157_resampled.wav')
# Resampled 'speech-librivox-0143.wav' to 44100 Hz (saved as 'speech-librivox-0143_resampled.wav')
# Resampled 'speech-librivox-0142.wav' to 44100 Hz (saved as 'speech-librivox-0142_resampled.wav')
# Resampled 'speech-librivox-0156.wav' to 44100 Hz (saved as 'speech-librivox-0156_resampled.wav')
# Resampled 'speech-librivox-0036.wav' to 44100 Hz (saved as 'speech-librivox-0036_resampled.wav')
# Resampled 'speech-librivox-0022.wav' to 44100 Hz (saved as 'speech-librivox-0022_resampled.wav')
# Resampled 'speech-librivox-0026.wav' to 44100 Hz (saved as 'speech-librivox-0026_resampled.wav')
# Resampled 'speech-librivox-0032.wav' to 44100 Hz (saved as 'speech-librivox-0032_resampled.wav')
# Resampled 'speech-librivox-0152.wav' to 44100 Hz (saved as 'speech-librivox-0152_resampled.wav')
# Resampled 'speech-librivox-0146.wav' to 44100 Hz (saved as 'speech-librivox-0146_resampled.wav')
# Resampled 'speech-librivox-0147.wav' to 44100 Hz (saved as 'speech-librivox-0147_resampled.wav')
# Resampled 'speech-librivox-0153.wav' to 44100 Hz (saved as 'speech-librivox-0153_resampled.wav')
# Resampled 'speech-librivox-0033.wav' to 44100 Hz (saved as 'speech-librivox-0033_resampled.wav')
# Resampled 'speech-librivox-0027.wav' to 44100 Hz (saved as 'speech-librivox-0027_resampled.wav')
# Resampled 'speech-librivox-0031.wav' to 44100 Hz (saved as 'speech-librivox-0031_resampled.wav')
# Resampled 'speech-librivox-0025.wav' to 44100 Hz (saved as 'speech-librivox-0025_resampled.wav')
# Resampled 'speech-librivox-0019.wav' to 44100 Hz (saved as 'speech-librivox-0019_resampled.wav')
# Resampled 'speech-librivox-0145.wav' to 44100 Hz (saved as 'speech-librivox-0145_resampled.wav')
# Resampled 'speech-librivox-0151.wav' to 44100 Hz (saved as 'speech-librivox-0151_resampled.wav')
# Resampled 'speech-librivox-0150.wav' to 44100 Hz (saved as 'speech-librivox-0150_resampled.wav')
# Resampled 'speech-librivox-0144.wav' to 44100 Hz (saved as 'speech-librivox-0144_resampled.wav')
# Resampled 'speech-librivox-0018.wav' to 44100 Hz (saved as 'speech-librivox-0018_resampled.wav')
# Resampled 'speech-librivox-0024.wav' to 44100 Hz (saved as 'speech-librivox-0024_resampled.wav')
# Resampled 'speech-librivox-0030.wav' to 44100 Hz (saved as 'speech-librivox-0030_resampled.wav')
# Resampled 'speech-librivox-0057.wav' to 44100 Hz (saved as 'speech-librivox-0057_resampled.wav')
# Resampled 'speech-librivox-0043.wav' to 44100 Hz (saved as 'speech-librivox-0043_resampled.wav')
# Resampled 'speech-librivox-0094.wav' to 44100 Hz (saved as 'speech-librivox-0094_resampled.wav')
# Resampled 'speech-librivox-0080.wav' to 44100 Hz (saved as 'speech-librivox-0080_resampled.wav')
# Resampled 'speech-librivox-0123.wav' to 44100 Hz (saved as 'speech-librivox-0123_resampled.wav')
# Resampled 'speech-librivox-0137.wav' to 44100 Hz (saved as 'speech-librivox-0137_resampled.wav')
# Resampled 'speech-librivox-0136.wav' to 44100 Hz (saved as 'speech-librivox-0136_resampled.wav')
# Resampled 'speech-librivox-0122.wav' to 44100 Hz (saved as 'speech-librivox-0122_resampled.wav')
# Resampled 'speech-librivox-0081.wav' to 44100 Hz (saved as 'speech-librivox-0081_resampled.wav')
# Resampled 'speech-librivox-0095.wav' to 44100 Hz (saved as 'speech-librivox-0095_resampled.wav')
# Resampled 'speech-librivox-0042.wav' to 44100 Hz (saved as 'speech-librivox-0042_resampled.wav')
# Resampled 'speech-librivox-0056.wav' to 44100 Hz (saved as 'speech-librivox-0056_resampled.wav')
# Resampled 'speech-librivox-0068.wav' to 44100 Hz (saved as 'speech-librivox-0068_resampled.wav')
# Resampled 'speech-librivox-0040.wav' to 44100 Hz (saved as 'speech-librivox-0040_resampled.wav')
# Resampled 'speech-librivox-0054.wav' to 44100 Hz (saved as 'speech-librivox-0054_resampled.wav')
# Resampled 'speech-librivox-0083.wav' to 44100 Hz (saved as 'speech-librivox-0083_resampled.wav')
# Resampled 'speech-librivox-0097.wav' to 44100 Hz (saved as 'speech-librivox-0097_resampled.wav')
# Resampled 'speech-librivox-0108.wav' to 44100 Hz (saved as 'speech-librivox-0108_resampled.wav')
# Resampled 'speech-librivox-0134.wav' to 44100 Hz (saved as 'speech-librivox-0134_resampled.wav')
# Resampled 'speech-librivox-0120.wav' to 44100 Hz (saved as 'speech-librivox-0120_resampled.wav')
# Resampled 'speech-librivox-0121.wav' to 44100 Hz (saved as 'speech-librivox-0121_resampled.wav')
# Resampled 'speech-librivox-0135.wav' to 44100 Hz (saved as 'speech-librivox-0135_resampled.wav')
# Resampled 'speech-librivox-0109.wav' to 44100 Hz (saved as 'speech-librivox-0109_resampled.wav')
# Resampled 'speech-librivox-0096.wav' to 44100 Hz (saved as 'speech-librivox-0096_resampled.wav')
# Resampled 'speech-librivox-0082.wav' to 44100 Hz (saved as 'speech-librivox-0082_resampled.wav')
# Resampled 'speech-librivox-0055.wav' to 44100 Hz (saved as 'speech-librivox-0055_resampled.wav')
# Resampled 'speech-librivox-0041.wav' to 44100 Hz (saved as 'speech-librivox-0041_resampled.wav')
# Resampled 'speech-librivox-0069.wav' to 44100 Hz (saved as 'speech-librivox-0069_resampled.wav')
# Resampled 'speech-librivox-0045.wav' to 44100 Hz (saved as 'speech-librivox-0045_resampled.wav')
# Resampled 'speech-librivox-0051.wav' to 44100 Hz (saved as 'speech-librivox-0051_resampled.wav')
# Resampled 'speech-librivox-0079.wav' to 44100 Hz (saved as 'speech-librivox-0079_resampled.wav')
# Resampled 'speech-librivox-0086.wav' to 44100 Hz (saved as 'speech-librivox-0086_resampled.wav')
# Resampled 'speech-librivox-0092.wav' to 44100 Hz (saved as 'speech-librivox-0092_resampled.wav')
# Resampled 'speech-librivox-0131.wav' to 44100 Hz (saved as 'speech-librivox-0131_resampled.wav')
# Resampled 'speech-librivox-0125.wav' to 44100 Hz (saved as 'speech-librivox-0125_resampled.wav')
# Resampled 'speech-librivox-0119.wav' to 44100 Hz (saved as 'speech-librivox-0119_resampled.wav')
# Resampled 'speech-librivox-0118.wav' to 44100 Hz (saved as 'speech-librivox-0118_resampled.wav')
# Resampled 'speech-librivox-0124.wav' to 44100 Hz (saved as 'speech-librivox-0124_resampled.wav')
# Resampled 'speech-librivox-0130.wav' to 44100 Hz (saved as 'speech-librivox-0130_resampled.wav')
# Resampled 'speech-librivox-0093.wav' to 44100 Hz (saved as 'speech-librivox-0093_resampled.wav')
# Resampled 'speech-librivox-0087.wav' to 44100 Hz (saved as 'speech-librivox-0087_resampled.wav')
# Resampled 'speech-librivox-0078.wav' to 44100 Hz (saved as 'speech-librivox-0078_resampled.wav')
# Resampled 'speech-librivox-0050.wav' to 44100 Hz (saved as 'speech-librivox-0050_resampled.wav')
# Resampled 'speech-librivox-0044.wav' to 44100 Hz (saved as 'speech-librivox-0044_resampled.wav')
# Resampled 'speech-librivox-0052.wav' to 44100 Hz (saved as 'speech-librivox-0052_resampled.wav')
# Resampled 'speech-librivox-0046.wav' to 44100 Hz (saved as 'speech-librivox-0046_resampled.wav')
# Resampled 'speech-librivox-0091.wav' to 44100 Hz (saved as 'speech-librivox-0091_resampled.wav')
# Resampled 'speech-librivox-0085.wav' to 44100 Hz (saved as 'speech-librivox-0085_resampled.wav')
# Resampled 'speech-librivox-0126.wav' to 44100 Hz (saved as 'speech-librivox-0126_resampled.wav')
# Resampled 'speech-librivox-0132.wav' to 44100 Hz (saved as 'speech-librivox-0132_resampled.wav')
# Resampled 'speech-librivox-0133.wav' to 44100 Hz (saved as 'speech-librivox-0133_resampled.wav')
# Resampled 'speech-librivox-0127.wav' to 44100 Hz (saved as 'speech-librivox-0127_resampled.wav')
# Resampled 'speech-librivox-0084.wav' to 44100 Hz (saved as 'speech-librivox-0084_resampled.wav')
# Resampled 'speech-librivox-0090.wav' to 44100 Hz (saved as 'speech-librivox-0090_resampled.wav')
# Resampled 'speech-librivox-0047.wav' to 44100 Hz (saved as 'speech-librivox-0047_resampled.wav')
# Resampled 'speech-librivox-0053.wav' to 44100 Hz (saved as 'speech-librivox-0053_resampled.wav')

# %% [markdown]
# ### Cut

# %%
def split_wav(input_file, output_dir, fragment_length=10):
  """
  Splits a wav file into 10-second fragments (or specified length) and saves them in the output directory.

  Args:
      input_file (str): Path to the wav file to split.
      output_dir (str): Path to the directory where fragments will be saved.
      fragment_length (int, optional): Length of each fragment in seconds. Defaults to 10.
  """
  with wave.open(input_file, mode="rb") as wav_file:
    # Get file parameters
    num_channels = wav_file.getnchannels()
    sample_width = wav_file.getsampwidth()
    framerate = wav_file.getframerate()

    # Calculate frame count per fragment
    frames_per_fragment = int(framerate * fragment_length)

    # Read frames in chunks
    frames = wav_file.readframes(frames_per_fragment)
    fragment_count = 0

    while frames:
      # Create output filename with format (original_filename}_{fragment_count}.wav
      output_filename = os.path.join(output_dir, f"{os.path.splitext(os.path.basename(input_file))[0]}_{fragment_count}.wav")
      
      # Open output file in write mode
      with wave.open(output_filename, mode="wb") as output_wav:
        output_wav.setnchannels(num_channels)
        output_wav.setsampwidth(sample_width)
        output_wav.setframerate(framerate)
        output_wav.writeframes(frames)

      fragment_count += 1
      frames = wav_file.readframes(frames_per_fragment)

# %%
os.makedirs("/Users/glebmokeev/Rask/data/music/clean/frag")

# %%
wav_folder = "/Users/glebmokeev/Rask/data/music/clean/resampled"
output_folder = "/Users/glebmokeev/Rask/data/music/clean/frag"

for filename in os.listdir(wav_folder):
  if filename.endswith(".wav"):
    full_path = os.path.join(wav_folder, filename)
    split_wav(full_path, output_folder)

# %%
os.makedirs("/Users/glebmokeev/Rask/data/vocals/mixed/audio/frag")

# %%
wav_folder = "/Users/glebmokeev/Rask/data/vocals/mixed/audio/resampled"
output_folder = "/Users/glebmokeev/Rask/data/vocals/mixed/audio/frag"

for filename in os.listdir(wav_folder):
  if filename.endswith(".wav"):
    full_path = os.path.join(wav_folder, filename)
    split_wav(full_path, output_folder)

# %% [markdown]
# ### Calculate new mean length

# %%
music_count, music_length = mean_length(os.path.join(data_dir, "music/clean/frag"))
print(f"Mean length {round(music_length/music_count, 3)} seconds")
# Out:
# Failed to proccess 0
# Mean length 9.91 seconds

# %%
music_count, music_length = mean_length(os.path.join(data_dir, "vocals/mixed/audio/frag"))
print(f"Mean length {round(music_length/music_count, 3)} seconds")
# Out:
# Failed to proccess 0
# Mean length 9.89 seconds

# %% [markdown]
# ### Play sounds using pydub

# %%
random_dir = os.path.join(data_dir, "music/clean/frag")
all_files = [f for f in os.listdir(random_dir) if not f.startswith('.')]
chosen_files = random.sample(all_files, 2)
full_paths = [os.path.join(random_dir, f) for f in chosen_files]
print(full_paths)
for path in full_paths:
    sound = AudioSegment.from_wav(path)
    play(sound)
# Out:
# ['/Users/glebmokeev/Rask/data/music/clean/frag/music-hd-0074_resampled_15.wav', '/Users/glebmokeev/Rask/data/music/clean/frag/musdb-sample56_resampled_74.wav']
# Input #0, wav, from '/var/folders/14/gktzbf5x5_18n56bjls0y7cw0000gn/T/tmpt4y9fium.wav':
#   Duration: 00:00:10.00, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
#    9.95 M-A: -0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
# Input #0, wav, from '/var/folders/14/gktzbf5x5_18n56bjls0y7cw0000gn/T/tmpgvaxw_n0.wav':
#   Duration: 00:00:10.00, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
#    9.94 M-A:  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0

# %% [markdown]
# ### IPython display audio

# %%
IPython.display.Audio("/Users/glebmokeev/Rask/data/music/clean/frag/musdb-sample48_resampled_12.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
